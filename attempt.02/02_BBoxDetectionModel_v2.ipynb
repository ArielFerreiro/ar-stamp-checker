# %% [markdown]
# <a href="https://colab.research.google.com/github/ArielFerreiro/ar-stamp-checker/blob/main/attempt.02/02_BBoxDetectionModel_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Using the resized BBoxes (224x224 images) we create a model to train it to detect the stamp in a picture.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# #### Load the drive to grab the images and labels

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #### Notebook Imports

# %%
import pickle
import os
import cv2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
from keras.applications.vgg19 import VGG19
from tensorflow.keras.models import save_model, load_model
from sklearn.model_selection import train_test_split

# %% [markdown]
# #### Global Params

# %%
images_path = 'drive/My Drive/Colab Notebooks/stamps/original/'
results_path = 'drive/My Drive/Colab Notebooks/stamps/results/'
models_path = 'drive/My Drive/Colab Notebooks/stamps/models/'

# %% [markdown]
# #### Start

# %%
with open(results_path+"bboxes_224.pkl","rb") as f:
    (stamps, bboxes) = pickle.load(f)
with open(results_path+"not_stamps.pkl","rb") as f:
    (not_stamps, ns_bboxes) = pickle.load(f)

# %%
stamps.shape, bboxes.shape, not_stamps.shape, ns_bboxes.shape
# Out:
# ((1888, 224, 224, 3), (1888, 10), (999, 224, 224, 3), (999, 10))

# %%
X = np.append(stamps, not_stamps, axis=0)
y = np.append(bboxes, ns_bboxes, axis=0)

# %%
X.shape, y.shape
# Out:
# ((2887, 224, 224, 3), (2887, 10))

# %%
stamps=0
bboxes=0
not_stamps=0
ns_boxes=0

# %%
# retain only the bounding boxes numbers (x,y,delta_x,delta_y)
y = y[:,1:5]
y.shape
# Out:
# (2887, 4)

# %%
y[y == ''] = 0.0
y = y.astype(np.float)

# %%
y.max(), X.max()
# Out:
# (193.0, 255)

# %%
# Normalize the datasets
y = y / y.max()
X = X / X.max()

# %%
# datasets creation
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=5, test_size=0.1)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((2598, 224, 224, 3), (289, 224, 224, 3), (2598, 4), (289, 4))

# %% [markdown]
# #### Model

# %%
model = VGG19(include_top=False, input_shape=(224, 224, 3))

# %%
# no training on first CNN layers
for layer in model.layers:
    layer.trainable = False

# %%
model.get_layer(name="block5_pool").output
# Out:
# <tf.Tensor 'block5_pool/MaxPool:0' shape=(None, 7, 7, 512) dtype=float32>

# %%
output = keras.layers.Flatten()(model.get_layer(name="block5_pool").output)
output = keras.layers.Dense(255)(output)
output = keras.layers.Activation("relu")(output)
output = keras.layers.Dense(4, activation="sigmoid")(output)

# %%
full_model = keras.models.Model(inputs=model.inputs, outputs=output)
#full_model.summary()

# %%
# Callbacks
checkpoint_file='checkpoint.pmi-cnn-vgg19.h5'
checkpointer = keras.callbacks.ModelCheckpoint(checkpoint_file, 
                                               monitor="val_mse", 
                                               verbose=1, 
                                               save_best_only=True,
                                               mode='min')

# %%
full_model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["mse"])

# %%
history = full_model.fit(X_train, y_train, 
           epochs=20, batch_size=12, 
           validation_data=(X_test, y_test), callbacks=[checkpointer])
# Out:
# Epoch 1/20
# 217/217 [==============================] - ETA: 0s - loss: 0.4847 - mse: 0.0133
# Epoch 00001: val_mse improved from inf to 0.00511, saving model to checkpoint.pmi-cnn-vgg19.h5
# 217/217 [==============================] - 18s 81ms/step - loss: 0.4847 - mse: 0.0133 - val_loss: 0.3887 - val_mse: 0.0051
# Epoch 2/20
# 217/217 [==============================] - ETA: 0s - loss: 0.4310 - mse: 0.0075
# Epoch 00002: val_mse improved from 0.00511 to 0.00418, saving model to checkpoint.pmi-cnn-vgg19.h5
# 217/217 [==============================] - 17s 77ms/step - loss: 0.4310 - mse: 0.0075 - val_loss: 0.3869 - val_mse: 0.0042
# Epoch 3/20
# 216/217 [============================>.] - ETA: 0s - loss: 0.4225 - mse: 0.0042
# Epoch 00003: val_mse improved from 0.00418 to 0.00190, saving model to checkpoint.pmi-cnn-vgg19.h5
# 217/217 [==============================] - 17s 78ms/step - loss: 0.4225 - mse: 0.0042 - val_loss: 0.3812 - val_mse: 0.0019
# Epoch 4/20
# 217/217 [==============================] - ETA: 0s - loss: 0.4165 - mse: 0.0017
# Epoch 00004: val_mse improved from 0.00190 to 0.00152, saving model to checkpoint.pmi-cnn-vgg19.h5
# 217/217 [==============================] - 18s 81ms/step - loss: 0.4165 - mse: 0.0017 - val_loss: 0.3806 - val_mse: 0.0015
# Epoch 5/20
# 217/217 [==============================] - ETA: 0s - loss: 0.4163 - mse: 0.0016
# Epoch 00005: val_mse improved from 0.00152 to 0.00102, saving model to checkpoint.pmi-cnn-vgg19.h5
# 217/217 [==============================] - 18s 83ms/step - loss: 0.4163 - mse: 0.0016 - val_loss: 0.3792 - val_mse: 0.0010
# Epoch 6/20
# 217/217 [==============================] - ETA: 0s - loss: 0.4152 - mse: 0.0011
# Epoch 00006: val_mse improved from 0.00102 to 0.00089, saving model to checkpoint.pmi-cnn-vgg19.h5
# 217/217 [==============================] - 19s 86ms/step - loss: 0.4152 - mse: 0.0011 - val_loss: 0.3792 - val_mse: 8.9104e-04
# Epoch 7/20
# 217/217 [==============================] - ETA: 0s - loss: 0.4142 - mse: 7.2557e-04
# Epoch 00007: val_mse did not improve from 0.00089
# 217/217 [==============================] - 18s 83ms/step - loss: 0.4142 - mse: 7.2557e-04 - val_loss: 0.3797 - val_mse: 0.0012
# Epoch 8/20
# 217/217 [==============================] - ETA: 0s - loss: 0.4141 - mse: 6.6177e-04
# Epoch 00008: val_mse improved from 0.00089 to 0.00062, saving model to checkpoint.pmi-cnn-vgg19.h5
# 217/217 [==============================] - 18s 83ms/step - loss: 0.4141 - mse: 6.6177e-04 - val_loss: 0.3784 - val_mse: 6.1589e-04
# Epoch 9/20
# 217/217 [==============================] - ETA: 0s - loss: 0.4140 - mse: 6.2654e-04
# Epoch 00009: val_mse did not improve from 0.00062
# 217/217 [==============================] - 18s 81ms/step - loss: 0.4140 - mse: 6.2654e-04 - val_loss: 0.3789 - val_mse: 8.7951e-04
# Epoch 10/20
# 217/217 [==============================] - ETA: 0s - loss: 0.4138 - mse: 5.3034e-04
# Epoch 00010: val_mse improved from 0.00062 to 0.00045, saving model to checkpoint.pmi-cnn-vgg19.h5
# 217/217 [==============================] - 18s 84ms/step - loss: 0.4138 - mse: 5.3034e-04 - val_loss: 0.3779 - val_mse: 4.5196e-04
# Epoch 11/20
# 217/217 [==============================] - ETA: 0s - loss: 0.4136 - mse: 4.6896e-04
# Epoch 00011: val_mse did not improve from 0.00045
# 217/217 [==============================] - 18s 82ms/step - loss: 0.4136 - mse: 4.6896e-04 - val_loss: 0.3789 - val_mse: 9.0466e-04
# Epoch 12/20
# 217/217 [==============================] - ETA: 0s - loss: 0.4136 - mse: 4.5602e-04
# Epoch 00012: val_mse did not improve from 0.00045
# 217/217 [==============================] - 18s 82ms/step - loss: 0.4136 - mse: 4.5602e-04 - val_loss: 0.3784 - val_mse: 6.5543e-04
# Epoch 13/20
# 217/217 [==============================] - ETA: 0s - loss: 0.4134 - mse: 4.0059e-04
# Epoch 00013: val_mse did not improve from 0.00045
# 217/217 [==============================] - 18s 82ms/step - loss: 0.4134 - mse: 4.0059e-04 - val_loss: 0.3780 - val_mse: 4.8594e-04
# Epoch 14/20
# 217/217 [==============================] - ETA: 0s - loss: 0.4133 - mse: 3.1379e-04
# Epoch 00014: val_mse did not improve from 0.00045
# 217/217 [==============================] - 18s 82ms/step - loss: 0.4133 - mse: 3.1379e-04 - val_loss: 0.3780 - val_mse: 5.0297e-04
# Epoch 15/20
# 217/217 [==============================] - ETA: 0s - loss: 0.4133 - mse: 3.2733e-04
# Epoch 00015: val_mse did not improve from 0.00045
# 217/217 [==============================] - 18s 82ms/step - loss: 0.4133 - mse: 3.2733e-04 - val_loss: 0.3781 - val_mse: 5.3457e-04
# Epoch 16/20
# 217/217 [==============================] - ETA: 0s - loss: 0.4131 - mse: 2.4947e-04
# Epoch 00016: val_mse improved from 0.00045 to 0.00038, saving model to checkpoint.pmi-cnn-vgg19.h5
# 217/217 [==============================] - 18s 84ms/step - loss: 0.4131 - mse: 2.4947e-04 - val_loss: 0.3777 - val_mse: 3.7705e-04
# Epoch 17/20
# 217/217 [==============================] - ETA: 0s - loss: 0.4130 - mse: 2.1977e-04
# Epoch 00017: val_mse improved from 0.00038 to 0.00037, saving model to checkpoint.pmi-cnn-vgg19.h5
# 217/217 [==============================] - 18s 84ms/step - loss: 0.4130 - mse: 2.1977e-04 - val_loss: 0.3777 - val_mse: 3.6846e-04
# Epoch 18/20
# 217/217 [==============================] - ETA: 0s - loss: 0.4132 - mse: 2.7508e-04
# Epoch 00018: val_mse did not improve from 0.00037
# 217/217 [==============================] - 18s 82ms/step - loss: 0.4132 - mse: 2.7508e-04 - val_loss: 0.3778 - val_mse: 4.0965e-04
# Epoch 19/20
# 217/217 [==============================] - ETA: 0s - loss: 0.4131 - mse: 2.4711e-04
# Epoch 00019: val_mse did not improve from 0.00037
# 217/217 [==============================] - 18s 82ms/step - loss: 0.4131 - mse: 2.4711e-04 - val_loss: 0.3778 - val_mse: 4.1370e-04
# Epoch 20/20
# 217/217 [==============================] - ETA: 0s - loss: 0.4130 - mse: 1.9307e-04
# Epoch 00020: val_mse did not improve from 0.00037
# 217/217 [==============================] - 18s 82ms/step - loss: 0.4130 - mse: 1.9307e-04 - val_loss: 0.3777 - val_mse: 3.7279e-04

# %%
# Check results
import matplotlib.pyplot as plt
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,6))
ax1.plot(history.history['loss'], label='train')
ax1.plot(history.history['val_loss'], label='val')
ax1.set_title('Loss - Cross Entropy')
ax1.legend()
ax2.plot(history.history['mse'], label='train')
ax2.plot(history.history['val_mse'], label='val')
ax2.set_title('Metric - MSE')
ax2.legend()
plt.show()

# %%
#Save the model
model_name = 'vgg19_bbox_detector.h5'
full_model.save(model_name)

# %% [markdown]
# #### Reset the notebook and start again (clean RAM)

# %%
from tensorflow.keras.models import save_model, load_model

model_name = 'vgg19_bbox_detector.h5'
checkpoint_file='checkpoint.pmi-cnn-vgg19.h5'

full_model = load_model(model_name, compile=True)
full_model.load_weights(checkpoint_file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-25822c061eb9> in <module>()
#       6 full_model = load_model(model_name, compile=True)
#       7 full_model.load_weights(checkpoint_file)
# ----> 8 full_model.evaluate(X, y)
#
# NameError: name 'X' is not defined

# %%
full_model.evaluate(X, y)
# Out:
# 91/91 [==============================] - 14s 153ms/step - loss: 0.4094 - mean_squared_error: 2.1157e-04
# [0.40943652391433716, 0.00021157479204703122]

# %% [markdown]
# #### Test

# %%
def check_predict(path, max_bbox=193):
  i = cv2.imread(path)
  i = cv2.resize(i, dsize=(224, 224))
  i = np.expand_dims(i, axis=0)
  i = i/i.max()
  prediccion = full_model.predict(i)
  bbox = prediccion[0]*max_bbox
  x, y, w, h = bbox
  crop = i[:, int(y):int(y+h), int(x):int(x+w), :]
  fig, ax = plt.subplots(1, 2, figsize=(15, 15))
  ax[0].imshow(i[0])
  ax[0].set_title("Given Image")
  ax[1].imshow(crop[0])
  ax[1].set_title("Estimated Box")
  plt.show()

# %%
path_img = images_path + 'cft_box/'
for x in range(10):
  check_predict(path_img+os.listdir(path_img)[x])

# %% [markdown]
# #### Save Model

# %%
model_name = 'vgg19_bbox_detector.h5'

full_model.save(models_path + model_name)
full_model.save_weights(models_path + 'weights_' + model_name)

# %% [markdown]
# #### Save model to TFLITE

# %%
# Convert the model.
converter = tf.lite.TFLiteConverter.from_keras_model(full_model)
tflite_model = converter.convert()

# Save the model.
with open(models_path + 'vgg19_bbox_detector.tflite', 'wb') as f:
  f.write(tflite_model)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: /tmp/tmpv3et93rq/assets

# %%
#### DONE v1 30/10/2020
#### Auth: Victor Vivas
